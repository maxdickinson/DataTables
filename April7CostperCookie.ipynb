# %%
import pandas as pd
import numpy as np

# %%
recXIngred = pd.read_csv('recipeXIngredientsApril4.csv')

# %%
recXIngred = recXIngred.fillna(0)

# %%
recXIngred = recXIngred.rename({'Unnamed: 0' : 'ingredients'} , axis =1)
recXIngred = recXIngred.set_index('ingredients')

# %%
costXIngredient = pd.read_excel('costOfIngredientsXStore.xlsx')

# %%
costXIngredient = costXIngredient.rename({'Unnamed: 0' : 'ingredients'} , axis =1)
costXIngredient = costXIngredient.set_index('ingredients')

# %%
costXIngredient = costXIngredient.drop('ingredients' , axis = 0)
costXIngredient = costXIngredient.infer_objects()
costXIngredient.info()

# %%
empty = pd.DataFrame([])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in np.arange(0,12,2):
    costXIngredient.insert(len(costXIngredient.columns) , 'pricePerOz' + costXIngredient.columns.to_list()[i] , costXIngredient.iloc[:,i]/costXIngredient.iloc[:,i+1])

# %%
costXIngredientXPerOz = costXIngredient.iloc[:,12::]

# %%
costXIngredientXPerOz.iloc[1,:].min()
# Out:
# 0.03125

# %%
costXIngredientXPerOz.iloc[1,:].idxmin()
# Out:
# 'pricePerOzWinco Bulk'

# %%
costXIngredient.columns[np.arange(0,12,2)]
# Out:
# Index(['Albertsons', 'Amazon(brand) ', 'Fred Meyers', 'Winco', 'Winco Bulk',
#        'Trader Joes'],
#       dtype='object')

# %%
costXIngredient
# Out:
#                                   Albertsons  Unnamed: 2  Amazon(brand)   \
# ingredients
# bobsRedMillwholeWheatPastryFlour         5.0        80.0            17.0
# bobsRedMillwholeWheaFlour                5.0        80.0            17.0
# GoldMedal allPuroseFlour                 5.0        80.0             4.5
#  AlmondFlour                            10.0        16.0            30.0
# quakerOats                               NaN         NaN             NaN
# ...                                      ...         ...             ...
#  nutritional yeast                       NaN         NaN            18.5
#  organic cane sugar                      NaN         NaN             NaN
# bakers flour                             NaN         NaN             NaN
#  premium bakers flour                    NaN         NaN             NaN
# gf bakers flour                          NaN         NaN             NaN
#
#                                   Unnamed: 4  Fred Meyers  Unnamed: 6  Winco  \
# ingredients
# bobsRedMillwholeWheatPastryFlour      1280.0         11.0        80.0    NaN
# bobsRedMillwholeWheaFlour               80.0          4.3        80.0    4.0
# GoldMedal allPuroseFlour                 5.0          4.6        80.0    NaN
#  AlmondFlour                            64.0          9.0        16.0    9.5
# quakerOats                               NaN          7.0        42.0    NaN
# ...                                      ...          ...         ...    ...
#  nutritional yeast                      16.0          6.0         4.5    5.7
#  organic cane sugar                      NaN          NaN         NaN    NaN
# bakers flour                             NaN          NaN         NaN    NaN
#  premium bakers flour                    NaN          NaN         NaN    NaN
# gf bakers flour                          NaN          NaN         NaN    NaN
#
#                                   Unnamed: 8  Winco Bulk  Unnamed: 10  \
# ingredients
# bobsRedMillwholeWheatPastryFlour         NaN         NaN          NaN
# bobsRedMillwholeWheaFlour               80.0        0.50         16.0
# GoldMedal allPuroseFlour                 NaN         NaN          NaN
#  AlmondFlour                            16.0        9.10         16.0
# quakerOats                               NaN        0.70         16.0
# ...                                      ...         ...          ...
#  nutritional yeast                       4.8        9.90         16.0
#  organic cane sugar                      NaN        1.40         16.0
# bakers flour                             NaN        0.48         16.0
#  premium bakers flour                    NaN        0.58         16.0
# gf bakers flour                          NaN        2.48         16.0
#
#                                   Trader Joes  Unnamed: 12  \
# ingredients
# bobsRedMillwholeWheatPastryFlour          NaN          NaN
# bobsRedMillwholeWheaFlour                 NaN          NaN
# GoldMedal allPuroseFlour                  NaN          NaN
#  AlmondFlour                             6.99         16.0
# quakerOats                                NaN          NaN
# ...                                       ...          ...
#  nutritional yeast                        NaN          NaN
#  organic cane sugar                       NaN          NaN
# bakers flour                              NaN          NaN
#  premium bakers flour                     NaN          NaN
# gf bakers flour                           NaN          NaN
#
#                                   pricePerOzAlbertsons  \
# ingredients
# bobsRedMillwholeWheatPastryFlour                0.0625
# bobsRedMillwholeWheaFlour                       0.0625
# GoldMedal allPuroseFlour                        0.0625
#  AlmondFlour                                    0.6250
# quakerOats                                         NaN
# ...                                                ...
#  nutritional yeast                                 NaN
#  organic cane sugar                                NaN
# bakers flour                                       NaN
#  premium bakers flour                              NaN
# gf bakers flour                                    NaN
#
#                                   pricePerOzAmazon(brand)   \
# ingredients
# bobsRedMillwholeWheatPastryFlour                  0.013281
# bobsRedMillwholeWheaFlour                         0.212500
# GoldMedal allPuroseFlour                          0.900000
#  AlmondFlour                                      0.468750
# quakerOats                                             NaN
# ...                                                    ...
#  nutritional yeast                                1.156250
#  organic cane sugar                                    NaN
# bakers flour                                           NaN
#  premium bakers flour                                  NaN
# gf bakers flour                                        NaN
#
#                                   pricePerOzFred Meyers  pricePerOzWinco  \
# ingredients
# bobsRedMillwholeWheatPastryFlour               0.137500              NaN
# bobsRedMillwholeWheaFlour                      0.053750          0.05000
# GoldMedal allPuroseFlour                       0.057500              NaN
#  AlmondFlour                                   0.562500          0.59375
# quakerOats                                     0.166667              NaN
# ...                                                 ...              ...
#  nutritional yeast                             1.333333          1.18750
#  organic cane sugar                                 NaN              NaN
# bakers flour                                        NaN              NaN
#  premium bakers flour                               NaN              NaN
# gf bakers flour                                     NaN              NaN
#
#                                   pricePerOzWinco Bulk  pricePerOzTrader Joes
# ingredients
# bobsRedMillwholeWheatPastryFlour                   NaN                    NaN
# bobsRedMillwholeWheaFlour                      0.03125                    NaN
# GoldMedal allPuroseFlour                           NaN                    NaN
#  AlmondFlour                                   0.56875               0.436875
# quakerOats                                     0.04375                    NaN
# ...                                                ...                    ...
#  nutritional yeast                             0.61875                    NaN
#  organic cane sugar                            0.08750                    NaN
# bakers flour                                   0.03000                    NaN
#  premium bakers flour                          0.03625                    NaN
# gf bakers flour                                0.15500                    NaN
#
# [65 rows x 18 columns]

# %%
costXIngredientXPerOz.insert(len(costXIngredientXPerOz.columns)) , ''

# %%
storeNames = costXIngredient.columns[np.arange(0,12,2)].to_list()

# %%
storeNames
# Out:
# ['Albertsons',
#  'Amazon(brand) ',
#  'Fred Meyers',
#  'Winco',
#  'Winco Bulk',
#  'Trader Joes']

# %%
storeMin = costXIngredientXPerOz.idxmin(axis = 1)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_28848\2762426431.py:1: FutureWarning: The behavior of DataFrame.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   storeMin = costXIngredientXPerOz.idxmin(axis = 1)

# %%
costMin = costXIngredientXPerOz.min(axis = 1)

# %%
costMin = costMin.rename('lowest Cost Per Oz')

# %%
storeMin = storeMin.rename('Store with Low Cost')

# %%
lows = pd.concat([costMin , storeMin] , axis = 1)

# %%
pd.concat([costXIngredient , lows] , axis =1)
# Out:
#                                   Albertsons  Unnamed: 2  Amazon(brand)   \
# ingredients
# bobsRedMillwholeWheatPastryFlour         5.0        80.0            17.0
# bobsRedMillwholeWheaFlour                5.0        80.0            17.0
# GoldMedal allPuroseFlour                 5.0        80.0             4.5
#  AlmondFlour                            10.0        16.0            30.0
# quakerOats                               NaN         NaN             NaN
# ...                                      ...         ...             ...
#  nutritional yeast                       NaN         NaN            18.5
#  organic cane sugar                      NaN         NaN             NaN
# bakers flour                             NaN         NaN             NaN
#  premium bakers flour                    NaN         NaN             NaN
# gf bakers flour                          NaN         NaN             NaN
#
#                                   Unnamed: 4  Fred Meyers  Unnamed: 6  Winco  \
# ingredients
# bobsRedMillwholeWheatPastryFlour      1280.0         11.0        80.0    NaN
# bobsRedMillwholeWheaFlour               80.0          4.3        80.0    4.0
# GoldMedal allPuroseFlour                 5.0          4.6        80.0    NaN
#  AlmondFlour                            64.0          9.0        16.0    9.5
# quakerOats                               NaN          7.0        42.0    NaN
# ...                                      ...          ...         ...    ...
#  nutritional yeast                      16.0          6.0         4.5    5.7
#  organic cane sugar                      NaN          NaN         NaN    NaN
# bakers flour                             NaN          NaN         NaN    NaN
#  premium bakers flour                    NaN          NaN         NaN    NaN
# gf bakers flour                          NaN          NaN         NaN    NaN
#
#                                   Unnamed: 8  Winco Bulk  Unnamed: 10  \
# ingredients
# bobsRedMillwholeWheatPastryFlour         NaN         NaN          NaN
# bobsRedMillwholeWheaFlour               80.0        0.50         16.0
# GoldMedal allPuroseFlour                 NaN         NaN          NaN
#  AlmondFlour                            16.0        9.10         16.0
# quakerOats                               NaN        0.70         16.0
# ...                                      ...         ...          ...
#  nutritional yeast                       4.8        9.90         16.0
#  organic cane sugar                      NaN        1.40         16.0
# bakers flour                             NaN        0.48         16.0
#  premium bakers flour                    NaN        0.58         16.0
# gf bakers flour                          NaN        2.48         16.0
#
#                                   Trader Joes  Unnamed: 12  \
# ingredients
# bobsRedMillwholeWheatPastryFlour          NaN          NaN
# bobsRedMillwholeWheaFlour                 NaN          NaN
# GoldMedal allPuroseFlour                  NaN          NaN
#  AlmondFlour                             6.99         16.0
# quakerOats                                NaN          NaN
# ...                                       ...          ...
#  nutritional yeast                        NaN          NaN
#  organic cane sugar                       NaN          NaN
# bakers flour                              NaN          NaN
#  premium bakers flour                     NaN          NaN
# gf bakers flour                           NaN          NaN
#
#                                   pricePerOzAlbertsons  \
# ingredients
# bobsRedMillwholeWheatPastryFlour                0.0625
# bobsRedMillwholeWheaFlour                       0.0625
# GoldMedal allPuroseFlour                        0.0625
#  AlmondFlour                                    0.6250
# quakerOats                                         NaN
# ...                                                ...
#  nutritional yeast                                 NaN
#  organic cane sugar                                NaN
# bakers flour                                       NaN
#  premium bakers flour                              NaN
# gf bakers flour                                    NaN
#
#                                   pricePerOzAmazon(brand)   \
# ingredients
# bobsRedMillwholeWheatPastryFlour                  0.013281
# bobsRedMillwholeWheaFlour                         0.212500
# GoldMedal allPuroseFlour                          0.900000
#  AlmondFlour                                      0.468750
# quakerOats                                             NaN
# ...                                                    ...
#  nutritional yeast                                1.156250
#  organic cane sugar                                    NaN
# bakers flour                                           NaN
#  premium bakers flour                                  NaN
# gf bakers flour                                        NaN
#
#                                   pricePerOzFred Meyers  pricePerOzWinco  \
# ingredients
# bobsRedMillwholeWheatPastryFlour               0.137500              NaN
# bobsRedMillwholeWheaFlour                      0.053750          0.05000
# GoldMedal allPuroseFlour                       0.057500              NaN
#  AlmondFlour                                   0.562500          0.59375
# quakerOats                                     0.166667              NaN
# ...                                                 ...              ...
#  nutritional yeast                             1.333333          1.18750
#  organic cane sugar                                 NaN              NaN
# bakers flour                                        NaN              NaN
#  premium bakers flour                               NaN              NaN
# gf bakers flour                                     NaN              NaN
#
#                                   pricePerOzWinco Bulk  pricePerOzTrader Joes  \
# ingredients
# bobsRedMillwholeWheatPastryFlour                   NaN                    NaN
# bobsRedMillwholeWheaFlour                      0.03125                    NaN
# GoldMedal allPuroseFlour                           NaN                    NaN
#  AlmondFlour                                   0.56875               0.436875
# quakerOats                                     0.04375                    NaN
# ...                                                ...                    ...
#  nutritional yeast                             0.61875                    NaN
#  organic cane sugar                            0.08750                    NaN
# bakers flour                                   0.03000                    NaN
#  premium bakers flour                          0.03625                    NaN
# gf bakers flour                                0.15500                    NaN
#
#                                   lowest Cost Per Oz       Store with Low Cost
# ingredients
# bobsRedMillwholeWheatPastryFlour            0.013281  pricePerOzAmazon(brand)
# bobsRedMillwholeWheaFlour                   0.031250      pricePerOzWinco Bulk
# GoldMedal allPuroseFlour                    0.057500     pricePerOzFred Meyers
#  AlmondFlour                                0.436875     pricePerOzTrader Joes
# quakerOats                                  0.043750      pricePerOzWinco Bulk
# ...                                              ...                       ...
#  nutritional yeast                          0.618750      pricePerOzWinco Bulk
#  organic cane sugar                         0.087500      pricePerOzWinco Bulk
# bakers flour                                0.030000      pricePerOzWinco Bulk
#  premium bakers flour                       0.036250      pricePerOzWinco Bulk
# gf bakers flour                             0.155000      pricePerOzWinco Bulk
#
# [65 rows x 20 columns]

# %%
matchIngredientNames = {' AlmondFlour':'AlmondFlour' , 'Crisco Vegtable Oil': 'vegtableOil','GoldMedal allPuroseFlour': 'allPuroseFlour' , 
                        'McCormickcardamom(teaspoons)' : 'cardamom(teaspoons)', 'McCormickcinamon(teaspoons)' : 'cinamon(teaspoons)',
       'McCormickcloves(teaspoons)' :  'cloves(teaspoons)', 'McCormickginger(teaspoons)':'ginger(teaspoons)' ,
       'McCormicknutmeg(teaspoons)' : 'nutmeg(teaspoons)', 'MonkFruitwithErythritol': 'wincoMonkFruitAndErythritol',
       'WholeWheatPastryFlour' :  'wincoWholeWheatPastryFlour' ,  'brm xanthamGum(teaspoons)' :  'xanthamGum(teaspoons)' ,
       'guitardChocolate Chips' :  'Chocolate Chips' , 'house canolaOil': 'canolaOil', 
       'quakerOats' : 'Oatmeal'}
dropColumns =  [' nutritional yeast' , ' organic cane sugar' , ' premium bakers flour' , 'Lemon Extract(teaspoons)' , 'bakers flour', 'better body food Coconut Oil', 
'monk fruit extact', 'gf bakers flour']

# %%
costXIngredMatchRecIngred = costXIngredient.drop(dropColumns , axis = 0)

# %%
recIngredForMul = recXIngred.drop(['ErythritlInWater', 'Powdered Erythritol',
       'Vegan Butter with AppleCider,yeast',
       'VeganBUTTER From Coco OOL, canolaoil, rapseedoil,nutritionalyeast ',
       'aquafabaButter', 'bulk suplements monk fruit extract',
       'naturesFlavorsButterExtract(teaspoons)', 'soy lecithin',
       'splendaInWater', 'water for Peanut Butter Powder'] , axis = 1)

# %%
costXIngredMatchRecIngred = costXIngredMatchRecIngred.rename(matchIngredientNames)

# %%
costXIngredient.rename({' AlmondFlour':'AlmondFlour'})
# Out:
#                                   Albertsons  Unnamed: 2  Amazon(brand)   \
# ingredients
# bobsRedMillwholeWheatPastryFlour         5.0        80.0            17.0
# bobsRedMillwholeWheaFlour                5.0        80.0            17.0
# GoldMedal allPuroseFlour                 5.0        80.0             4.5
# AlmondFlour                             10.0        16.0            30.0
# quakerOats                               NaN         NaN             NaN
# ...                                      ...         ...             ...
#  nutritional yeast                       NaN         NaN            18.5
#  organic cane sugar                      NaN         NaN             NaN
# bakers flour                             NaN         NaN             NaN
#  premium bakers flour                    NaN         NaN             NaN
# gf bakers flour                          NaN         NaN             NaN
#
#                                   Unnamed: 4  Fred Meyers  Unnamed: 6  Winco  \
# ingredients
# bobsRedMillwholeWheatPastryFlour      1280.0         11.0        80.0    NaN
# bobsRedMillwholeWheaFlour               80.0          4.3        80.0    4.0
# GoldMedal allPuroseFlour                 5.0          4.6        80.0    NaN
# AlmondFlour                             64.0          9.0        16.0    9.5
# quakerOats                               NaN          7.0        42.0    NaN
# ...                                      ...          ...         ...    ...
#  nutritional yeast                      16.0          6.0         4.5    5.7
#  organic cane sugar                      NaN          NaN         NaN    NaN
# bakers flour                             NaN          NaN         NaN    NaN
#  premium bakers flour                    NaN          NaN         NaN    NaN
# gf bakers flour                          NaN          NaN         NaN    NaN
#
#                                   Unnamed: 8  Winco Bulk  Unnamed: 10  \
# ingredients
# bobsRedMillwholeWheatPastryFlour         NaN         NaN          NaN
# bobsRedMillwholeWheaFlour               80.0        0.50         16.0
# GoldMedal allPuroseFlour                 NaN         NaN          NaN
# AlmondFlour                             16.0        9.10         16.0
# quakerOats                               NaN        0.70         16.0
# ...                                      ...         ...          ...
#  nutritional yeast                       4.8        9.90         16.0
#  organic cane sugar                      NaN        1.40         16.0
# bakers flour                             NaN        0.48         16.0
#  premium bakers flour                    NaN        0.58         16.0
# gf bakers flour                          NaN        2.48         16.0
#
#                                   Trader Joes  Unnamed: 12  \
# ingredients
# bobsRedMillwholeWheatPastryFlour          NaN          NaN
# bobsRedMillwholeWheaFlour                 NaN          NaN
# GoldMedal allPuroseFlour                  NaN          NaN
# AlmondFlour                              6.99         16.0
# quakerOats                                NaN          NaN
# ...                                       ...          ...
#  nutritional yeast                        NaN          NaN
#  organic cane sugar                       NaN          NaN
# bakers flour                              NaN          NaN
#  premium bakers flour                     NaN          NaN
# gf bakers flour                           NaN          NaN
#
#                                   pricePerOzAlbertsons  \
# ingredients
# bobsRedMillwholeWheatPastryFlour                0.0625
# bobsRedMillwholeWheaFlour                       0.0625
# GoldMedal allPuroseFlour                        0.0625
# AlmondFlour                                     0.6250
# quakerOats                                         NaN
# ...                                                ...
#  nutritional yeast                                 NaN
#  organic cane sugar                                NaN
# bakers flour                                       NaN
#  premium bakers flour                              NaN
# gf bakers flour                                    NaN
#
#                                   pricePerOzAmazon(brand)   \
# ingredients
# bobsRedMillwholeWheatPastryFlour                  0.013281
# bobsRedMillwholeWheaFlour                         0.212500
# GoldMedal allPuroseFlour                          0.900000
# AlmondFlour                                       0.468750
# quakerOats                                             NaN
# ...                                                    ...
#  nutritional yeast                                1.156250
#  organic cane sugar                                    NaN
# bakers flour                                           NaN
#  premium bakers flour                                  NaN
# gf bakers flour                                        NaN
#
#                                   pricePerOzFred Meyers  pricePerOzWinco  \
# ingredients
# bobsRedMillwholeWheatPastryFlour               0.137500              NaN
# bobsRedMillwholeWheaFlour                      0.053750          0.05000
# GoldMedal allPuroseFlour                       0.057500              NaN
# AlmondFlour                                    0.562500          0.59375
# quakerOats                                     0.166667              NaN
# ...                                                 ...              ...
#  nutritional yeast                             1.333333          1.18750
#  organic cane sugar                                 NaN              NaN
# bakers flour                                        NaN              NaN
#  premium bakers flour                               NaN              NaN
# gf bakers flour                                     NaN              NaN
#
#                                   pricePerOzWinco Bulk  pricePerOzTrader Joes
# ingredients
# bobsRedMillwholeWheatPastryFlour                   NaN                    NaN
# bobsRedMillwholeWheaFlour                      0.03125                    NaN
# GoldMedal allPuroseFlour                           NaN                    NaN
# AlmondFlour                                    0.56875               0.436875
# quakerOats                                     0.04375                    NaN
# ...                                                ...                    ...
#  nutritional yeast                             0.61875                    NaN
#  organic cane sugar                            0.08750                    NaN
# bakers flour                                   0.03000                    NaN
#  premium bakers flour                          0.03625                    NaN
# gf bakers flour                                0.15500                    NaN
#
# [65 rows x 18 columns]
